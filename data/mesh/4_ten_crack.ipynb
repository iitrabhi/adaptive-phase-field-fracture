# %% [markdown]
# # A9

# %%
import gmsh

gmsh.initialize()

gmsh.model.add("glacier_terminus")

# -------------------------------------------------------------------------
# Geometry dimensions [m]
# -------------------------------------------------------------------------

Lx = 500.0
Ly = 750.0
Lz = 125.0

# -------------------------------------------------------------------------
# Notch dimensions [m]
# -------------------------------------------------------------------------

lx = 5.0
ly = 20.0
lz = 10.0

# Spacing between notch centers [m]
s = 70.0

# -------------------------------------------------------------------------
# Mesh size controls [m]
# -------------------------------------------------------------------------

h_min = 5.0
h_max = 18

# Local crack-tip refinement
h_refined = 5

refinement_x = 10.0
refinement_y = 10.0
refinement_z = 10.0

transition_thickness = 10.0

gmsh.option.setNumber("Mesh.MeshSizeMin", h_min)
gmsh.option.setNumber("Mesh.MeshSizeMax", h_max)
gmsh.option.setNumber("Mesh.MeshSizeFactor", 1.0)

# -------------------------------------------------------------------------
# Glacier geometry
# -------------------------------------------------------------------------

glacier = gmsh.model.occ.addBox(
    0.0,
    0.0,
    0.0,
    Lx,
    Ly,
    Lz,
)

# -------------------------------------------------------------------------
# Five equally spaced notch locations
#
# Centers:
#   Lx/2 - 2s
#   Lx/2 - s
#   Lx/2
#   Lx/2 + s
#   Lx/2 + 2s
#
# Same five notches are placed on:
#   y = 0
#   y = Ly
# -------------------------------------------------------------------------

x_center = 0.5 * Lx

notch_centers = [
    x_center - 2.0 * s,
    x_center - 1.0 * s,
    x_center,
    x_center + 1.0 * s,
    x_center + 2.0 * s,
]

notches = []

for xc in notch_centers:

    # ---------------------------------------------------------------------
    # Notch on y = 0 side
    # ---------------------------------------------------------------------

    notch_bottom = gmsh.model.occ.addBox(
        xc - 0.5 * lx,
        0.0,
        Lz - lz,
        lx,
        ly,
        lz,
    )

    notches.append((3, notch_bottom))

    # ---------------------------------------------------------------------
    # Opposite notch on y = Ly side
    # ---------------------------------------------------------------------

    notch_top = gmsh.model.occ.addBox(
        xc - 0.5 * lx,
        Ly - ly,
        Lz - lz,
        lx,
        ly,
        lz,
    )

    notches.append((3, notch_top))

# -------------------------------------------------------------------------
# Subtract all 10 notches
# -------------------------------------------------------------------------

domain, _ = gmsh.model.occ.cut(
    [(3, glacier)],
    notches,
    removeObject=True,
    removeTool=True,
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Internal planes
#
# z = Lz / 4 = 31.25 m
# z = Lz / 2 = 62.50 m
# -------------------------------------------------------------------------

z_quarter = Lz / 4.0
z_half = Lz / 2.0

plane_quarter = gmsh.model.occ.addRectangle(
    0.0,
    0.0,
    z_quarter,
    Lx,
    Ly,
)

plane_half = gmsh.model.occ.addRectangle(
    0.0,
    0.0,
    z_half,
    Lx,
    Ly,
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Fragment glacier with internal planes
# -------------------------------------------------------------------------

domain, _ = gmsh.model.occ.fragment(
    domain,
    [
        (2, plane_quarter),
        (2, plane_half),
    ],
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Physical volume
# -------------------------------------------------------------------------

volume_tags = [
    tag
    for dim, tag in domain
    if dim == 3
]

gmsh.model.addPhysicalGroup(
    3,
    volume_tags,
    1,
)

gmsh.model.setPhysicalName(
    3,
    1,
    "GLACIER",
)

# -------------------------------------------------------------------------
# Local refinement around all 10 crack tips
# -------------------------------------------------------------------------

refinement_fields = []

crack_tip_z = Lz - lz

for xc in notch_centers:

    # ---------------------------------------------------------------------
    # Crack tip on y = 0 side
    #
    # Tip location:
    # x = xc
    # y = ly
    # z = Lz - lz
    # ---------------------------------------------------------------------

    crack_tip_y_bottom = ly

    field_bottom = gmsh.model.mesh.field.add("Box")

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "VIn",
        h_refined,
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "VOut",
        h_max,
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "XMin",
        xc - refinement_x,
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "XMax",
        xc + refinement_x,
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "YMin",
        max(
            0.0,
            crack_tip_y_bottom - refinement_y,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "YMax",
        min(
            Ly,
            crack_tip_y_bottom + refinement_y,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "ZMin",
        max(
            0.0,
            crack_tip_z - refinement_z,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "ZMax",
        Lz,
    )

    gmsh.model.mesh.field.setNumber(
        field_bottom,
        "Thickness",
        transition_thickness,
    )

    refinement_fields.append(field_bottom)

    # ---------------------------------------------------------------------
    # Crack tip on y = Ly side
    #
    # Tip location:
    # x = xc
    # y = Ly - ly
    # z = Lz - lz
    # ---------------------------------------------------------------------

    crack_tip_y_top = Ly - ly

    field_top = gmsh.model.mesh.field.add("Box")

    gmsh.model.mesh.field.setNumber(
        field_top,
        "VIn",
        h_refined,
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "VOut",
        h_max,
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "XMin",
        xc - refinement_x,
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "XMax",
        xc + refinement_x,
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "YMin",
        max(
            0.0,
            crack_tip_y_top - refinement_y,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "YMax",
        min(
            Ly,
            crack_tip_y_top + refinement_y,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "ZMin",
        max(
            0.0,
            crack_tip_z - refinement_z,
        ),
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "ZMax",
        Lz,
    )

    gmsh.model.mesh.field.setNumber(
        field_top,
        "Thickness",
        transition_thickness,
    )

    refinement_fields.append(field_top)

# -------------------------------------------------------------------------
# Combine all 10 refinement regions
# -------------------------------------------------------------------------

field_min = gmsh.model.mesh.field.add("Min")

gmsh.model.mesh.field.setNumbers(
    field_min,
    "FieldsList",
    refinement_fields,
)

gmsh.model.mesh.field.setAsBackgroundMesh(
    field_min
)

# -------------------------------------------------------------------------
# Mesh settings
# -------------------------------------------------------------------------

gmsh.option.setNumber(
    "Mesh.Algorithm3D",
    10,
)

gmsh.option.setNumber(
    "Mesh.MeshSizeFromCurvature",
    0,
)

gmsh.option.setNumber(
    "Mesh.MeshSizeFromPoints",
    0,
)

gmsh.option.setNumber(
    "Mesh.MeshSizeExtendFromBoundary",
    0,
)

# -------------------------------------------------------------------------
# Generate tetrahedral mesh
# -------------------------------------------------------------------------

gmsh.model.mesh.generate(3)

# -------------------------------------------------------------------------
# Output
# -------------------------------------------------------------------------

gmsh.write("09/Lx500_10C_S70.msh")

gmsh.finalize()
# Out:
# Info    : Meshing 1D...nts
# Info    : [  0%] Meshing curve 154 (Line)
# Info    : [ 10%] Meshing curve 155 (Line)
# Info    : [ 10%] Meshing curve 156 (Line)
# Info    : [ 10%] Meshing curve 157 (Line)
# Info    : [ 10%] Meshing curve 158 (Line)
# Info    : [ 10%] Meshing curve 159 (Line)
# Info    : [ 10%] Meshing curve 160 (Line)
# Info    : [ 10%] Meshing curve 161 (Line)
# Info    : [ 10%] Meshing curve 162 (Line)
# Info    : [ 10%] Meshing curve 163 (Line)
# Info    : [ 10%] Meshing curve 164 (Line)
# Info    : [ 10%] Meshing curve 165 (Line)
# Info    : [ 10%] Meshing curve 166 (Line)
# Info    : [ 10%] Meshing curve 167 (Line)
# Info    : [ 10%] Meshing curve 168 (Line)
# Info    : [ 20%] Meshing curve 169 (Line)
# Info    : [ 20%] Meshing curve 170 (Line)
# Info    : [ 20%] Meshing curve 171 (Line)
# Info    : [ 20%] Meshing curve 172 (Line)
# Info    : [ 20%] Meshing curve 173 (Line)
# Info    : [ 20%] Meshing curve 174 (Line)
# Info    : [ 20%] Meshing curve 175 (Line)
# Info    : [100%] Meshing curve 295 (Line)
# Info    : [100%] Meshing curve 296 (Line)
# Info    : [100%] Meshing curve 297 (Line)
# Info    : [100%] Meshing curve 298 (Line)
# Info    : [100%] Meshing curve 299 (Line)
# Info    : [100%] Meshing curve 300 (Line)
# Info    : [100%] Meshing curve 301 (Line)
# Info    : Done meshing 1D (Wall 0.0202424s, CPU 0.021032s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 72 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 73 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 74 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 75 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 76 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 77 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 78 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 79 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 80 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 81 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 82 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 83 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 84 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 85 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 86 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 87 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 88 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 89 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 90 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 91 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 92 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 93 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 94 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 95 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 96 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 97 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 98 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 99 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 100 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 101 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 102 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 103 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 104 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 105 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 106 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 107 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 108 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 109 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 110 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 111 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 112 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 113 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 114 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 115 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 116 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 117 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 118 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 119 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 120 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 121 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 122 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 123 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 124 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 125 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 126 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 127 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.144488s, CPU 0.145611s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 3 volumes with 1 connected component
# Info    : Input mesh hash bb7f62982a635688
# Info    : Creating an empty mesh with 7133 vertices
# Info    : Initialization of tet. mesh
# Info    : Delaunay of       7129 points on   1 threads - mesh.nvert: 4
# Info    : Recovering 2 missing facet(s)
# Info    : Recover Delaunay
# Info    : All volumes of the BRep were found and colorized accordingly
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of       7867 points on   1 threads - mesh.nvert: 7133
# Info    :           -       6957 points filtered
# Info    :           =        910 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of       2440 points on   1 threads - mesh.nvert: 8043
# Info    :           -       1689 points filtered
# Info    :           =        751 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of        379 points on   1 threads - mesh.nvert: 8794
# Info    :           -        187 points filtered
# Info    :           =        192 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of         39 points on   1 threads - mesh.nvert: 8986
# Info    :           -         14 points filtered
# Info    :           =         25 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of          2 points on   1 threads - mesh.nvert: 9011
# Info    :           -          1 points filtered
# Info    :           =          1 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Improving       1296 tet. on   1 thrd (S & ER)
# Info    : Improving         81 tet. on   1 thrd (S & ER)
# Info    : Improving         23 tet. on   1 thrd (S & ER)
# Info    : Improving         17 tet. on   1 thrd (S & ER)
# Info    : Improving         15 tet. on   1 thrd (S & ER)
# Info    : Improving         15 tet. on   1 thrd (GSC)
# Info    : Improving          4 tet. on   1 thrd (S & ER)
# Info    : Improving          3 tet. on   1 thrd (S & ER)
# Info    : Improving          3 tet. on   1 thrd (GSC)
# Info    :  	Final tet. mesh contains 49740 tetrahedra
# Info    :  	Final tet. mesh contains 9012 vertices
# Info    : tEmptyMesh  	 = 	    0.031
# Info    : tVerifyBnd  	 = 	    0.004
# Info    : tBndRecovery	 = 	    0.041
# Info    : tConvertMesh	 = 	    0.003
# Info    : tRefine     	 = 	    0.030
# Info    : tOptimize   	 = 	    0.008
# Info    : Done meshing 3D (Wall 0.135837s, CPU 0.1292s)
# Info    : 9012 nodes 55780 elements
# Info    : Writing '09/Lx500_10C_S70.msh'...
# Info    : Done writing '09/Lx500_10C_S70.msh'

# %% [markdown]
# # XDMF - A9

# %%
import meshio

mesh_files = ["09/Lx500_10C_S70.msh"]

for mesh_file in mesh_files:
    mesh = meshio.read(mesh_file)
    cells = mesh.get_cells_type("tetra")
    points = mesh.points

    meshio.write(
        mesh_file.replace(".msh", ".xdmf"),
        meshio.Mesh(
            points=points,
            cells={"tetra": cells},
        ),
    )

# %%
import gmsh
import os

gmsh.initialize()

gmsh.model.add("glacier_terminus_10C_S70_outline")

# -------------------------------------------------------------------------
# Geometry dimensions [m]
# -------------------------------------------------------------------------

Lx = 500.0
Ly = 750.0
Lz = 125.0

# -------------------------------------------------------------------------
# Notch dimensions [m]
# -------------------------------------------------------------------------

lx = 5.0
ly = 10.0
lz = 10.0

# Spacing between notch centers [m]
s = 70.0

# -------------------------------------------------------------------------
# Outline mesh size controls [m]
# -------------------------------------------------------------------------

h_min = 1.0
h_max = 18.0

gmsh.option.setNumber(
    "Mesh.MeshSizeMin",
    h_min,
)

gmsh.option.setNumber(
    "Mesh.MeshSizeMax",
    h_max,
)

gmsh.option.setNumber(
    "Mesh.MeshSizeFactor",
    1.0,
)

# -------------------------------------------------------------------------
# Glacier geometry
# -------------------------------------------------------------------------

glacier = gmsh.model.occ.addBox(
    0.0,
    0.0,
    0.0,
    Lx,
    Ly,
    Lz,
)

# -------------------------------------------------------------------------
# Five equally spaced notch locations
#
# Centers:
#   Lx/2 - 2s
#   Lx/2 - s
#   Lx/2
#   Lx/2 + s
#   Lx/2 + 2s
#
# Same five notches are placed on:
#   y = 0
#   y = Ly
# -------------------------------------------------------------------------

x_center = 0.5 * Lx

notch_centers = [
    x_center - 2.0 * s,
    x_center - 1.0 * s,
    x_center,
    x_center + 1.0 * s,
    x_center + 2.0 * s,
]

notches = []

for xc in notch_centers:

    # ---------------------------------------------------------------------
    # Notch on y = 0 side
    # ---------------------------------------------------------------------

    notch_bottom = gmsh.model.occ.addBox(
        xc - 0.5 * lx,
        0.0,
        Lz - lz,
        lx,
        ly,
        lz,
    )

    notches.append(
        (3, notch_bottom)
    )

    # ---------------------------------------------------------------------
    # Opposite notch on y = Ly side
    # ---------------------------------------------------------------------

    notch_top = gmsh.model.occ.addBox(
        xc - 0.5 * lx,
        Ly - ly,
        Lz - lz,
        lx,
        ly,
        lz,
    )

    notches.append(
        (3, notch_top)
    )

# -------------------------------------------------------------------------
# Subtract all 10 notches
# -------------------------------------------------------------------------

domain, _ = gmsh.model.occ.cut(
    [(3, glacier)],
    notches,
    removeObject=True,
    removeTool=True,
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Internal planes
#
# z = Lz / 4 = 31.25 m
# z = Lz / 2 = 62.50 m
# -------------------------------------------------------------------------

z_quarter = Lz / 4.0
z_half = Lz / 2.0

plane_quarter = gmsh.model.occ.addRectangle(
    0.0,
    0.0,
    z_quarter,
    Lx,
    Ly,
)

plane_half = gmsh.model.occ.addRectangle(
    0.0,
    0.0,
    z_half,
    Lx,
    Ly,
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Fragment glacier with internal planes
#
# This creates geometric edges at z = Lz/4 and z = Lz/2,
# which will appear in the 1D outline mesh.
# -------------------------------------------------------------------------

domain, _ = gmsh.model.occ.fragment(
    domain,
    [
        (2, plane_quarter),
        (2, plane_half),
    ],
)

gmsh.model.occ.synchronize()

# -------------------------------------------------------------------------
# Get all geometric curves
# -------------------------------------------------------------------------

curves = gmsh.model.getEntities(1)

curve_tags = [
    tag
    for dim, tag in curves
]

# -------------------------------------------------------------------------
# Physical group for 1D outline
# -------------------------------------------------------------------------

if curve_tags:

    gmsh.model.addPhysicalGroup(
        1,
        curve_tags,
        1,
    )

    gmsh.model.setPhysicalName(
        1,
        1,
        "OUTLINE",
    )

# -------------------------------------------------------------------------
# Generate ONLY 1D line mesh
# -------------------------------------------------------------------------

gmsh.model.mesh.generate(1)

# -------------------------------------------------------------------------
# Output
#
# 09/Lx500_10C_S70_outline.msh
# -------------------------------------------------------------------------

os.makedirs(
    "09",
    exist_ok=True,
)

filename = "09/Lx500_10C_S70_outline.msh"

gmsh.write(filename)

print(f"Generated: {filename}")

gmsh.finalize()
# Out:
# Info    : Meshing 1D...nts
# Info    : [  0%] Meshing curve 154 (Line)
# Info    : [ 10%] Meshing curve 155 (Line)
# Info    : [ 10%] Meshing curve 156 (Line)
# Info    : [ 10%] Meshing curve 157 (Line)
# Info    : [ 10%] Meshing curve 158 (Line)
# Info    : [ 10%] Meshing curve 159 (Line)
# Info    : [ 10%] Meshing curve 160 (Line)
# Info    : [ 10%] Meshing curve 161 (Line)
# Info    : [ 10%] Meshing curve 162 (Line)
# Info    : [ 10%] Meshing curve 163 (Line)
# Info    : [ 10%] Meshing curve 164 (Line)
# Info    : [ 10%] Meshing curve 165 (Line)
# Info    : [ 10%] Meshing curve 166 (Line)
# Info    : [ 10%] Meshing curve 167 (Line)
# Info    : [ 10%] Meshing curve 168 (Line)
# Info    : [ 20%] Meshing curve 169 (Line)
# Info    : [ 20%] Meshing curve 170 (Line)
# Info    : [ 20%] Meshing curve 171 (Line)
# Info    : [ 20%] Meshing curve 172 (Line)
# Info    : [ 20%] Meshing curve 173 (Line)
# Info    : [ 20%] Meshing curve 174 (Line)
# Info    : [ 20%] Meshing curve 175 (Line)
# Info    : [ 20%] Meshing curve 176 (Line)
# Info    : [ 20%] Meshing curve 177 (Line)
# Info    : [ 20%] Meshing curve 178 (Line)
# Info    : [ 20%] Meshing curve 179 (Line)
# Info    : [ 20%] Meshing curve 180 (Line)
# Info    : [ 20%] Meshing curve 181 (Line)
# Info    : [ 20%] Meshing curve 182 (Line)
# Info    : [ 20%] Meshing curve 183 (Line)
# Info    : [ 30%] Meshing curve 184 (Line)
# Info    : [ 30%] Meshing curve 185 (Line)
# Info    : [ 30%] Meshing curve 186 (Line)
# Info    : [ 30%] Meshing curve 187 (Line)
# Info    : [ 30%] Meshing curve 188 (Line)
# Info    : [ 30%] Meshing curve 189 (Line)
# Info    : [ 30%] Meshing curve 190 (Line)
# Info    : [ 30%] Meshing curve 191 (Line)
# Info    : [ 30%] Meshing curve 192 (Line)
# Info    : [ 30%] Meshing curve 193 (Line)
# Info    : [ 30%] Meshing curve 194 (Line)
# Info    : [ 30%] Meshing curve 195 (Line)
# Info    : [ 30%] Meshing curve 196 (Line)
# Info    : [ 30%] Meshing curve 197 (Line)
# Info    : [ 30%] Meshing curve 198 (Line)
# Info    : [ 40%] Meshing curve 199 (Line)
# Info    : [ 40%] Meshing curve 200 (Line)
# Info    : [ 40%] Meshing curve 201 (Line)
# Info    : [ 40%] Meshing curve 202 (Line)
# Info    : [ 40%] Meshing curve 203 (Line)
# Info    : [ 40%] Meshing curve 204 (Line)
# Info    : [ 40%] Meshing curve 205 (Line)
# Info    : [ 40%] Meshing curve 206 (Line)
# Info    : [ 40%] Meshing curve 207 (Line)
# Info    : [ 40%] Meshing curve 208 (Line)
# Info    : [ 40%] Meshing curve 209 (Line)
# Info    : [ 40%] Meshing curve 210 (Line)
# Info    : [ 40%] Meshing curve 211 (Line)
# Info    : [ 40%] Meshing curve 212 (Line)
# Info    : [ 40%] Meshing curve 213 (Line)
# Info    : [ 50%] Meshing curve 214 (Line)
# Info    : [ 50%] Meshing curve 215 (Line)
# Info    : [ 50%] Meshing curve 216 (Line)
# Info    : [ 50%] Meshing curve 217 (Line)
# Info    : [ 50%] Meshing curve 218 (Line)
# Info    : [ 50%] Meshing curve 219 (Line)
# Info    : [ 50%] Meshing curve 220 (Line)
# Info    : [ 50%] Meshing curve 221 (Line)
# Info    : [ 50%] Meshing curve 222 (Line)
# Info    : [ 50%] Meshing curve 223 (Line)
# Info    : [ 50%] Meshing curve 224 (Line)
# Info    : [ 50%] Meshing curve 225 (Line)
# Info    : [ 50%] Meshing curve 226 (Line)
# Info    : [ 50%] Meshing curve 227 (Line)
# Info    : [ 60%] Meshing curve 228 (Line)
# Info    : [ 60%] Meshing curve 229 (Line)
# Info    : [ 60%] Meshing curve 230 (Line)
# Info    : [ 60%] Meshing curve 231 (Line)
# Info    : [ 60%] Meshing curve 232 (Line)
# Info    : [ 60%] Meshing curve 233 (Line)
# Info    : [ 60%] Meshing curve 234 (Line)
# Info    : [ 60%] Meshing curve 235 (Line)
# Info    : [ 60%] Meshing curve 236 (Line)
# Info    : [ 60%] Meshing curve 237 (Line)
# Info    : [ 60%] Meshing curve 238 (Line)
# Info    : [ 60%] Meshing curve 239 (Line)
# Info    : [ 60%] Meshing curve 240 (Line)
# Info    : [ 60%] Meshing curve 241 (Line)
# Info    : [ 60%] Meshing curve 242 (Line)
# Info    : [ 70%] Meshing curve 243 (Line)
# Info    : [ 70%] Meshing curve 244 (Line)
# Info    : [ 70%] Meshing curve 245 (Line)
# Info    : [ 70%] Meshing curve 246 (Line)
# Info    : [ 70%] Meshing curve 247 (Line)
# Info    : [ 70%] Meshing curve 248 (Line)
# Info    : [ 70%] Meshing curve 249 (Line)
# Info    : [ 70%] Meshing curve 250 (Line)
# Info    : [ 70%] Meshing curve 251 (Line)
# Info    : [ 70%] Meshing curve 252 (Line)
# Info    : [ 70%] Meshing curve 253 (Line)
# Info    : [ 70%] Meshing curve 254 (Line)
# Info    : [ 70%] Meshing curve 255 (Line)
# Info    : [ 70%] Meshing curve 256 (Line)
# Info    : [ 70%] Meshing curve 257 (Line)
# Info    : [ 80%] Meshing curve 258 (Line)
# Info    : [ 80%] Meshing curve 259 (Line)
# Info    : [ 80%] Meshing curve 260 (Line)
# Info    : [ 80%] Meshing curve 261 (Line)
# Info    : [ 80%] Meshing curve 262 (Line)
# Info    : [ 80%] Meshing curve 263 (Line)
# Info    : [ 80%] Meshing curve 264 (Line)
# Info    : [ 80%] Meshing curve 265 (Line)
# Info    : [ 80%] Meshing curve 266 (Line)
# Info    : [ 80%] Meshing curve 267 (Line)
# Info    : [ 80%] Meshing curve 268 (Line)
# Info    : [ 80%] Meshing curve 269 (Line)
# Info    : [ 80%] Meshing curve 270 (Line)
# Info    : [ 80%] Meshing curve 271 (Line)
# Info    : [ 80%] Meshing curve 272 (Line)
# Info    : [ 90%] Meshing curve 273 (Line)
# Info    : [ 90%] Meshing curve 274 (Line)
# Info    : [ 90%] Meshing curve 275 (Line)
# Info    : [ 90%] Meshing curve 276 (Line)
# Info    : [ 90%] Meshing curve 277 (Line)
# Info    : [ 90%] Meshing curve 278 (Line)
# Info    : [ 90%] Meshing curve 279 (Line)
# Info    : [ 90%] Meshing curve 280 (Line)
# Info    : [ 90%] Meshing curve 281 (Line)
# Info    : [ 90%] Meshing curve 282 (Line)
# Info    : [ 90%] Meshing curve 283 (Line)
# Info    : [ 90%] Meshing curve 284 (Line)
# Info    : [ 90%] Meshing curve 285 (Line)
# Info    : [ 90%] Meshing curve 286 (Line)
# Info    : [ 90%] Meshing curve 287 (Line)
# Info    : [100%] Meshing curve 288 (Line)
# Info    : [100%] Meshing curve 289 (Line)
# Info    : [100%] Meshing curve 290 (Line)
# Info    : [100%] Meshing curve 291 (Line)
# Info    : [100%] Meshing curve 292 (Line)
# Info    : [100%] Meshing curve 293 (Line)
# Info    : [100%] Meshing curve 294 (Line)
# Info    : [100%] Meshing curve 295 (Line)
# Info    : [100%] Meshing curve 296 (Line)
# Info    : [100%] Meshing curve 297 (Line)
# Info    : [100%] Meshing curve 298 (Line)
# Info    : [100%] Meshing curve 299 (Line)
# Info    : [100%] Meshing curve 300 (Line)
# Info    : [100%] Meshing curve 301 (Line)
# Info    : Done meshing 1D (Wall 0.00335408s, CPU 0.004507s)
# Info    : 650 nodes 798 elements
# Info    : Writing '09/Lx500_10C_S70_outline.msh'...
# Generated: 09/Lx500_10C_S70_outline.msh
# Info    : Done writing '09/Lx500_10C_S70_outline.msh'

# %% [markdown]
# # Outline - XDMF

# %%
import meshio

mesh_files = ["09/Lx500_10C_S70_outline.msh"]

for mesh_file in mesh_files:
    mesh = meshio.read(mesh_file)
    cells = mesh.get_cells_type("line")
    points = mesh.points

    meshio.write(
        mesh_file.replace(".msh", ".xdmf"),
        meshio.Mesh(
            points=points,
            cells={"line": cells},
        ),
    )
