# %% [markdown]
# # Stress state within a prestine ground glacier.

# %% [markdown]
# In this code, we'll gain insight into the behaviour of  pristine glaciers that are land terminating and ocean terminating. Mimicking the conditions relevant to grounded glaciers, a free slip condition is applied to the bottom surface, restraining the displacement in the vertical direction. The normal component of the displacement field at the far left edge is restrained to prevent rigid body motion in the horizontal direction. The top surface, representing the atmosphere–ice interface, is defined as a free boundary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1: Preprocessing
# - Define units: N, m
# - Prepare the design basis report

# %% [markdown]
# ## Step 2: Importing Necessary Libraries

# %%
from dolfin import *
import ufl
from helpers import *
from problem_definition import *
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Step 3: Loading the Mesh

# %%
mesh = Mesh()
with XDMFFile("mesh/glacier_2d_single_crack.xdmf") as infile:
    infile.read(mesh)

# %%
mesh.hmin()
# Out:
# 2.017494417920321

# %% [markdown]
# ## Step 4: Preparing the sets

# %%
support_left = CompiledSubDomain("on_boundary && near(x[0], 0.0, tol)", tol=1e-14)
support_bottom = CompiledSubDomain("on_boundary && near(x[1],0.0, tol)", tol=1e-14)
load_right = CompiledSubDomain("on_boundary && x[1]<= 62.5 && x[0]==500")

mf_line = MeshFunction("size_t", mesh, 1)
load_right.mark(mf_line, 1)

ds = Measure("ds")(subdomain_data=mf_line)

# %% [markdown]
# ## Step 5: Preparing output file

# %%
xdmf = XDMFFile("output/solution.xdmf")
xdmf.parameters["functions_share_mesh"] = True
xdmf.parameters["rewrite_function_mesh"] = False
xdmf.parameters["flush_output"] = True

# %% [markdown]
# ## Step 6: Defining  spaces

# %%
V1 = VectorFunctionSpace(mesh, "CG", 1)
F1 = FunctionSpace(mesh, "CG", 1)

FDG0 = FunctionSpace(mesh, "DG", 0)
TDG0 = TensorFunctionSpace(mesh, "DG", 0)

# %% [markdown]
# ## Step 7: Define functions

# %%
u, v = TrialFunction(V1), TestFunction(V1)
unew, uold = Function(V1, name="disp"), Function(V1, name="disp")
stress_xx, cdf = Function(F1, name="sigma_xx"), Function(FDG0, name="cdf")

# %%
p, q = TrialFunction(F1), TestFunction(F1)
pnew, pold = Function(F1, name="damage"), Function(F1, name="damage")

# %% [markdown]
# ## Step 8: Material Model

# %%
# N, m, Pa
g = 9.81
rho_sea = 1020
E0_ice = 9500e6
nu_ice = 0.35
rho_i_ice = 917 
sigma_c_ice = 0.1185e6

# %%
l = 10 #0.625

# %%
ci = 2
threshold = 15
ice = MaterialModel(E0_ice, nu_ice, rho_i_ice, sigma_c_ice, ci, threshold)

# %% [markdown]
# ## Step 9: Define supports

# %%
bc_sp_x = DirichletBC(V1.sub(0), Constant(0.0), support_left)
bc_sp_x2 = DirichletBC(V1.sub(1), Constant(0.0), support_bottom)
bc_u = [bc_sp_x, bc_sp_x2]

# %% [markdown]
# ## Step 10: Define Loads

# %%
# t = Expression(("(125/4 - x[1] >= 0 ? - rho  * (125/4 - x[1]) : 0.0)", 0), rho=rho_sea*g, degree=1)
# t = Expression(("(125/2 - x[1] >= 0 ? - rho  * (125/2 - x[1]) : 0.0)", 0), rho=rho_sea*g, degree=1)
t = Constant((0, 0))
f = Constant((0, -ice.rho * g))

# %% [markdown]
# ## Step 11: Define the problem

# %%
load_switch = conditional(
        gt(pnew, 0.6),
        0.0,
        1.0,
    )
a_disp = inner(degradation(pnew) * ice.stress(u), ice.strain(v)) * dx
L_disp = load_switch *dot(f, v) * dx + dot(t, v) * ds(1)

# %%
a_phase = ((1 + cdf) * inner(p, q) + l**2 * inner(grad(p), grad(q))) * dx
L_phase = inner(cdf, q) * dx

# %% [markdown]
# ## Step 12: Solve

# %%
disp_problem = LinearVariationalProblem(a_disp, L_disp, unew, bc_u)
phase_problem = LinearVariationalProblem(a_phase, L_phase, pnew)

# %%
problem = FractureProblem(disp_problem, phase_problem, ice, cdf)
solver = FractureSolver(problem)

# %%
prm = solver.parameters
prm["time_start"] = 0.0
prm["time_total"] = 150.0
prm["delta_t"] = 1.0
prm["multi_staggered"]["tolerance"] = 1e-5
prm["multi_staggered"]["maximum_iterations"] = 1

# %%
solver.solve(xdmf)
# Out:
# Solving linear variational problem.
# Solving linear variational problem.
# step:   0.0, dof:     35703, hmin:  2.02 time:      0
# Solving linear variational problem.
# Solving linear variational problem.
# step:   1.0, dof:     35703, hmin:  2.02 time:      0
# Solving linear variational problem.
# Solving linear variational problem.
# step:   2.0, dof:     35703, hmin:  2.02 time:      0
# Solving linear variational problem.
# Solving linear variational problem.
# step:   3.0, dof:     35703, hmin:  2.02 time:      0
# Solving linear variational problem.
# Solving linear variational problem.
# step:   4.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:   5.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:   6.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:   7.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:   8.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:   9.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:  10.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:  11.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:  12.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:  13.0, dof:     35703, hmin:  2.02 time:      1
# Solving linear variational problem.
# Solving linear variational problem.
# step:  14.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  15.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  16.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  17.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  18.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  19.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  20.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  21.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  22.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  23.0, dof:     35703, hmin:  2.02 time:      2
# Solving linear variational problem.
# Solving linear variational problem.
# step:  24.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  25.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  26.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  27.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  28.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  29.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  30.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  31.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  32.0, dof:     35703, hmin:  2.02 time:      3
# Solving linear variational problem.
# Solving linear variational problem.
# step:  33.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  34.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  35.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  36.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  37.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  38.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  39.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  40.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  41.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  42.0, dof:     35703, hmin:  2.02 time:      4
# Solving linear variational problem.
# Solving linear variational problem.
# step:  43.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  44.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  45.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  46.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  47.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  48.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  49.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  50.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  51.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  52.0, dof:     35703, hmin:  2.02 time:      5
# Solving linear variational problem.
# Solving linear variational problem.
# step:  53.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  54.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  55.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  56.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  57.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  58.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  59.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  60.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  61.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  62.0, dof:     35703, hmin:  2.02 time:      6
# Solving linear variational problem.
# Solving linear variational problem.
# step:  63.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  64.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  65.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  66.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  67.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  68.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  69.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  70.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  71.0, dof:     35703, hmin:  2.02 time:      7
# Solving linear variational problem.
# Solving linear variational problem.
# step:  72.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  73.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  74.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  75.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  76.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  77.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  78.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  79.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  80.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  81.0, dof:     35703, hmin:  2.02 time:      8
# Solving linear variational problem.
# Solving linear variational problem.
# step:  82.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  83.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  84.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  85.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  86.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  87.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  88.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  89.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  90.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  91.0, dof:     35703, hmin:  2.02 time:      9
# Solving linear variational problem.
# Solving linear variational problem.
# step:  92.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  93.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  94.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  95.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  96.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  97.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  98.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step:  99.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step: 100.0, dof:     35703, hmin:  2.02 time:     10
# Solving linear variational problem.
# Solving linear variational problem.
# step: 101.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 102.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 103.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 104.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 105.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 106.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 107.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 108.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# step: 109.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# step: 110.0, dof:     35703, hmin:  2.02 time:     11
# Solving linear variational problem.
# Solving linear variational problem.
# step: 111.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 112.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 113.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 114.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 115.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 116.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 117.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 118.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 119.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 120.0, dof:     35703, hmin:  2.02 time:     12
# Solving linear variational problem.
# Solving linear variational problem.
# step: 121.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 122.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 123.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 124.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 125.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 126.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 127.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 128.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 129.0, dof:     35703, hmin:  2.02 time:     13
# Solving linear variational problem.
# Solving linear variational problem.
# step: 130.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 131.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 132.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 133.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 134.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 135.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 136.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 137.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 138.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 139.0, dof:     35703, hmin:  2.02 time:     14
# Solving linear variational problem.
# Solving linear variational problem.
# step: 140.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 141.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 142.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 143.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 144.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 145.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 146.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 147.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 148.0, dof:     35703, hmin:  2.02 time:     15
# Solving linear variational problem.
# Solving linear variational problem.
# step: 149.0, dof:     35703, hmin:  2.02 time:     16
# Solving linear variational problem.
# Solving linear variational problem.
# step: 150.0, dof:     35703, hmin:  2.02 time:     16

# %%
plot(unew, mode="displacement")

# %%
plt.figure(figsize=(18, 6))
c = plot(pnew)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %% [markdown]
# ## Step 13: Post processing

# %%
stress_xx.assign(project(ice.stress(unew)[0, 0] / 1e6, FDG0))  # N/m2 -> MPa
cdf.assign(project(ice.get_crack_driving_force(unew), FDG0))

# %%
plt.figure(figsize=(18, 6))
c = plot(stress_xx)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
plt.figure(figsize=(18, 6))
c = plot(cdf)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
# xdmf.write(unew, 0)
# xdmf.write(stress_xx, 0)
# xdmf.write(cdf, 0)
# xdmf.close()

# %%
# import pyvista as pv
import numpy as np

# %%
import numpy as np


def get_damage_isoline_bottom(damage, damage_threshold=0.5):
    mesh = damage.function_space().mesh()

    coordinates = mesh.coordinates()
    cells = mesh.cells()
    damage_values = damage.compute_vertex_values(mesh)

    contour_points = []

    for cell in cells:
        pts = coordinates[cell]
        vals = damage_values[cell]

        edges = [
            (0, 1),
            (1, 2),
            (2, 0),
        ]

        for i, j in edges:
            vi = vals[i]
            vj = vals[j]

            if (vi - damage_threshold) * (vj - damage_threshold) > 0:
                continue

            if abs(vj - vi) < 1e-14:
                continue

            alpha = (damage_threshold - vi) / (vj - vi)

            if 0.0 <= alpha <= 1.0:
                point = pts[i] + alpha * (pts[j] - pts[i])
                contour_points.append(point)

    if len(contour_points) == 0:
        raise ValueError(
            "No damage={} iso-line found.".format(damage_threshold)
        )

    contour_points = np.asarray(contour_points)

    i = np.argmin(contour_points[:, 1])

    bottom_point = contour_points[i].copy()

    ymin = float(bottom_point[1])

    return ymin, bottom_point

# %%
ymin, bottom_point = get_damage_isoline_bottom(
    pnew,
    damage_threshold=0.5,
)

print("Bottom of damage iso-line:", bottom_point)
print("Minimum y:", ymin)
# Out:
# Bottom of damage iso-line: [249.32617754  12.24404628]
# Minimum y: 12.244046284271505
